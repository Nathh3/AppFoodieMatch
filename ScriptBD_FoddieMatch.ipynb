-- %% [markdown]
-- # [FoodieMatchBD]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [FoodieMatchBD]    Script Date: 13/11/2025 12:09:38 p. m. ******/
CREATE DATABASE [FoodieMatchBD]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'FoodieMatchBD', FILENAME = N'/var/opt/mssql/data/FoodieMatchBD.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'FoodieMatchBD_log', FILENAME = N'/var/opt/mssql/data/FoodieMatchBD_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [FoodieMatchBD] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [FoodieMatchBD].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [FoodieMatchBD] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET ARITHABORT OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [FoodieMatchBD] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [FoodieMatchBD] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET  ENABLE_BROKER 
GO
ALTER DATABASE [FoodieMatchBD] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [FoodieMatchBD] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET RECOVERY FULL 
GO
ALTER DATABASE [FoodieMatchBD] SET  MULTI_USER 
GO
ALTER DATABASE [FoodieMatchBD] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [FoodieMatchBD] SET DB_CHAINING OFF 
GO
ALTER DATABASE [FoodieMatchBD] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [FoodieMatchBD] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [FoodieMatchBD] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [FoodieMatchBD] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'FoodieMatchBD', N'ON'
GO
ALTER DATABASE [FoodieMatchBD] SET QUERY_STORE = ON
GO
ALTER DATABASE [FoodieMatchBD] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categoria]

-- %%
USE [FoodieMatchBD]
GO

-- %%
/****** Object:  Table [dbo].[Categoria]    Script Date: 13/11/2025 12:09:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categoria](
	[CategoriaId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[CategoriaId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Eleccion]

-- %%
/****** Object:  Table [dbo].[Eleccion]    Script Date: 13/11/2025 12:09:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Eleccion](
	[EleccionId] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[ProductoId] [int] NOT NULL,
	[FechaEleccion] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[EleccionId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
/****** Object:  Table [dbo].[Producto]    Script Date: 13/11/2025 12:09:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Producto](
	[ProductoId] [int] IDENTITY(1,1) NOT NULL,
	[RestauranteId] [int] NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Descripcion] [nvarchar](255) NOT NULL,
	[Precio] [decimal](18, 2) NOT NULL,
	[Imagen_URL] [nvarchar](max) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ProductoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Restaurante]

-- %%
/****** Object:  Table [dbo].[Restaurante]    Script Date: 13/11/2025 12:09:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Restaurante](
	[RestauranteId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Telefono] [nvarchar](100) NOT NULL,
	[Direccion] [nvarchar](255) NOT NULL,
	[Longitud] [decimal](18, 2) NOT NULL,
	[Latitud] [decimal](18, 2) NOT NULL,
	[CategoriaId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[RestauranteId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Telefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 13/11/2025 12:09:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[UsuarioId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[PasswordHash] [nvarchar](100) NOT NULL,
	[Direccion] [nvarchar](255) NOT NULL,
	[Longitud] [decimal](18, 2) NOT NULL,
	[Latitud] [decimal](18, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Eleccion__FechaE__44FF419A]

-- %%
ALTER TABLE [dbo].[Eleccion] ADD  DEFAULT (getdate()) FOR [FechaEleccion]
GO

-- %% [markdown]
-- # [FK__Eleccion__Produc__440B1D61]

-- %%
ALTER TABLE [dbo].[Eleccion]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Producto] ([ProductoId])
GO

-- %% [markdown]
-- # [FK__Eleccion__Usuari__4316F928]

-- %%
ALTER TABLE [dbo].[Eleccion]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuario] ([UsuarioId])
GO

-- %% [markdown]
-- # [FK__Producto__Restau__403A8C7D]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD FOREIGN KEY([RestauranteId])
REFERENCES [dbo].[Restaurante] ([RestauranteId])
GO

-- %% [markdown]
-- # [FK__Restauran__Categ__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Restaurante]  WITH CHECK ADD FOREIGN KEY([CategoriaId])
REFERENCES [dbo].[Categoria] ([CategoriaId])
GO

-- %% [markdown]
-- # [FoodieMatchBD]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [FoodieMatchBD] SET  READ_WRITE 
GO
